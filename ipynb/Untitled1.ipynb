# %%
import numpy as np
x = np.arange(6).reshape(2,3)
y = np.arange(6).reshape(2,3)

# %%
a
# Out:
# array([[0, 1, 2],
#        [3, 4, 5]])

# %%
a.ndim
# Out:
# 2

# %%
b = np.arange(6).reshape(2,3)

# %%
b
# Out:
# array([[0, 1, 2],
#        [3, 4, 5]])

# %%
def add(x,y):
#     assert len(x.shape) == 2 
#     assert x.shape == y.shape
    x = x.copy() 
    for i in range(x.shape[0]):
        for j in range(x.shape[1]):
             x[i, j] += y[i, j]
    return x

# %%
add(3,4)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-27-763ed6ac3064> in <module>
# ----> 1 add(3,4)
#
# <ipython-input-26-0946f22d0bb5> in add(x, y)
#       2 #     assert len(x.shape) == 2
#       3 #     assert x.shape == y.shape
# ----> 4     x = x.copy()
#       5     for i in range(x.shape[0]):
#       6         for j in range(x.shape[1]):
#
# AttributeError: 'int' object has no attribute 'copy'

# %%
z= x+y

# %%
z = np.maximum(z,0)

# %%
z
# Out:
# array([[ 0,  2,  4],
#        [ 6,  8, 10]])

# %%
x = np.random.random((64, 3, 132, 10)) 
y = np.random.random((10)) 
z = np.maximum(x, y)

# %%
z
# Out:
# array([[[[0.82072125, 0.91962279, 0.32546571, ..., 0.31654533,
#           0.6657584 , 0.7726001 ],
#          [0.75706005, 0.91962279, 0.59280685, ..., 0.1622871 ,
#           0.58230893, 0.7726001 ],
#          [0.75706005, 0.91962279, 0.63714721, ..., 0.46096418,
#           0.58230893, 0.88329855],
#          ...,
#          [0.75706005, 0.91962279, 0.32546571, ..., 0.8972192 ,
#           0.58230893, 0.7726001 ],
#          [0.75706005, 0.95496875, 0.32546571, ..., 0.36563077,
#           0.58230893, 0.7726001 ],
#          [0.75706005, 0.91962279, 0.32546571, ..., 0.11432296,
#           0.58230893, 0.7726001 ]],
#
#         [[0.75706005, 0.91962279, 0.49485683, ..., 0.17299367,
#           0.75947407, 0.7726001 ],
#          [0.98486455, 0.91962279, 0.87098879, ..., 0.84531715,
#           0.58230893, 0.7726001 ],
#          [0.75706005, 0.91962279, 0.60112781, ..., 0.66091278,
#           0.58230893, 0.7726001 ],
#          ...,
#          [0.75706005, 0.91962279, 0.96163942, ..., 0.29918618,
#           0.58230893, 0.7726001 ],
#          [0.75706005, 0.91962279, 0.87353687, ..., 0.79490888,
#           0.62790678, 0.7726001 ],
#          [0.75706005, 0.91962279, 0.51739406, ..., 0.35319153,
#           0.58230893, 0.7726001 ]],
#
#         [[0.75706005, 0.91962279, 0.83355464, ..., 0.07366457,
#           0.69450757, 0.7726001 ],
#          [0.98683993, 0.91962279, 0.9821576 , ..., 0.70059534,
#           0.76772007, 0.7726001 ],
#          [0.87555161, 0.91962279, 0.62622883, ..., 0.07366457,
#           0.58230893, 0.96957651],
#          ...,
#          [0.76127816, 0.91962279, 0.76537866, ..., 0.91026738,
#           0.58230893, 0.99835121],
#          [0.75706005, 0.91962279, 0.53184847, ..., 0.56678113,
#           0.58230893, 0.7726001 ],
#          [0.75706005, 0.91962279, 0.37682437, ..., 0.08950609,
#           0.58230893, 0.7726001 ]]],
#
#
#        [[[0.75706005, 0.91962279, 0.56934474, ..., 0.19988664,
#           0.68982581, 0.7726001 ],
#          [0.88546468, 0.91962279, 0.37498139, ..., 0.86299775,
#           0.58230893, 0.8915518 ],
#          [0.79943612, 0.91962279, 0.32546571, ..., 0.08081267,
#           0.58230893, 0.96003828],
#          ...,
#          [0.75706005, 0.91962279, 0.86285977, ..., 0.07366457,
#           0.58230893, 0.7726001 ],
#          [0.89973507, 0.91962279, 0.32546571, ..., 0.13073226,
#           0.58230893, 0.81147627],
#          [0.75706005, 0.91962279, 0.32546571, ..., 0.80869895,
#           0.83883309, 0.7726001 ]],
#
#         [[0.75706005, 0.91962279, 0.91134141, ..., 0.98326548,
#           0.58230893, 0.95637752],
#          [0.75706005, 0.91962279, 0.9672413 , ..., 0.52717972,
#           0.58230893, 0.7726001 ],
#          [0.75706005, 0.91962279, 0.38349836, ..., 0.3074884 ,
#           0.75505635, 0.83416176],
#          ...,
#          [0.75706005, 0.91962279, 0.32546571, ..., 0.22390031,
#           0.58230893, 0.7726001 ],
#          [0.75706005, 0.91962279, 0.82282035, ..., 0.28270184,
#           0.58230893, 0.7726001 ],
#          [0.75706005, 0.91962279, 0.32546571, ..., 0.12342086,
#           0.58230893, 0.7726001 ]],
#
#         [[0.75706005, 0.91962279, 0.32546571, ..., 0.15193758,
#           0.58230893, 0.7726001 ],
#          [0.96776197, 0.91962279, 0.98685884, ..., 0.17846736,
#           0.58230893, 0.84842193],
#          [0.75706005, 0.91962279, 0.97324505, ..., 0.29547958,
#           0.58230893, 0.7726001 ],
#          ...,
#          [0.75706005, 0.91962279, 0.32546571, ..., 0.13759634,
#           0.70745429, 0.88387002],
#          [0.75706005, 0.91962279, 0.32546571, ..., 0.22620044,
#           0.58230893, 0.7726001 ],
#          [0.75706005, 0.91962279, 0.32546571, ..., 0.85510494,
#           0.58230893, 0.7726001 ]]],
#
#
#        [[[0.75706005, 0.91962279, 0.48016475, ..., 0.07366457,
#           0.58230893, 0.79740982],
#          [0.75706005, 0.91962279, 0.85023779, ..., 0.69291966,
#           0.84246683, 0.7726001 ],
#          [0.75706005, 0.91962279, 0.5091557 , ..., 0.50550041,
#           0.58230893, 0.7726001 ],
#          ...,
#          [0.75706005, 0.91962279, 0.98459432, ..., 0.25007031,
#           0.58230893, 0.92834562],
#          [0.75706005, 0.91962279, 0.80436913, ..., 0.07366457,
#           0.69152529, 0.7726001 ],
#          [0.75706005, 0.91962279, 0.84848737, ..., 0.07366457,
#           0.58230893, 0.7726001 ]],
#
#         [[0.92968732, 0.91962279, 0.81991125, ..., 0.94313144,
#           0.83928737, 0.7726001 ],
#          [0.75706005, 0.91962279, 0.4331798 , ..., 0.07366457,
#           0.58230893, 0.7726001 ],
#          [0.75706005, 0.91962279, 0.54903852, ..., 0.98428757,
#           0.58230893, 0.7726001 ],
#          ...,
#          [0.75706005, 0.91962279, 0.32546571, ..., 0.66627863,
#           0.58230893, 0.7726001 ],
#          [0.75706005, 0.91962279, 0.32546571, ..., 0.39114073,
#           0.58230893, 0.7726001 ],
#          [0.75706005, 0.91962279, 0.32546571, ..., 0.50882519,
#           0.83522989, 0.7726001 ]],
#
#         [[0.99642339, 0.93347198, 0.62583407, ..., 0.45671002,
#           0.82569639, 0.7726001 ],
#          [0.75706005, 0.91962279, 0.90008707, ..., 0.28813568,
#           0.95987191, 0.98906716],
#          [0.75706005, 0.91962279, 0.32546571, ..., 0.09034523,
#           0.84970618, 0.7726001 ],
#          ...,
#          [0.87848611, 0.91962279, 0.45372662, ..., 0.20039843,
#           0.58230893, 0.7726001 ],
#          [0.75706005, 0.91962279, 0.90233309, ..., 0.67450512,
#           0.58230893, 0.7726001 ],
#          [0.75706005, 0.91962279, 0.85648118, ..., 0.85092856,
#           0.96683123, 0.7726001 ]]],
#
#
#        ...,
#
#
#        [[[0.91318808, 0.91962279, 0.51703748, ..., 0.25962051,
#           0.98505907, 0.7726001 ],
#          [0.75706005, 0.91962279, 0.32546571, ..., 0.07366457,
#           0.58230893, 0.7726001 ],
#          [0.98122899, 0.91962279, 0.5164161 , ..., 0.61345367,
#           0.86474071, 0.7726001 ],
#          ...,
#          [0.83167576, 0.91962279, 0.39994741, ..., 0.98337809,
#           0.87396087, 0.7726001 ],
#          [0.75706005, 0.91962279, 0.60779909, ..., 0.15570353,
#           0.58230893, 0.7726001 ],
#          [0.75706005, 0.91962279, 0.61786523, ..., 0.84828286,
#           0.58230893, 0.7726001 ]],
#
#         [[0.75706005, 0.96299805, 0.85666032, ..., 0.07366457,
#           0.86124569, 0.7726001 ],
#          [0.75706005, 0.91962279, 0.53601897, ..., 0.62085831,
#           0.8565747 , 0.7726001 ],
#          [0.75706005, 0.91962279, 0.32546571, ..., 0.69618414,
#           0.75889145, 0.7726001 ],
#          ...,
#          [0.75706005, 0.91962279, 0.32546571, ..., 0.9769173 ,
#           0.91414701, 0.7726001 ],
#          [0.75706005, 0.91962279, 0.98211796, ..., 0.96565087,
#           0.71821843, 0.7726001 ],
#          [0.75706005, 0.91962279, 0.52444565, ..., 0.1266664 ,
#           0.58230893, 0.7726001 ]],
#
#         [[0.97235488, 0.91962279, 0.32546571, ..., 0.35518792,
#           0.58230893, 0.7726001 ],
#          [0.75706005, 0.91962279, 0.66734191, ..., 0.07366457,
#           0.90019982, 0.7726001 ],
#          [0.86657802, 0.91962279, 0.66982732, ..., 0.69733154,
#           0.58230893, 0.7726001 ],
#          ...,
#          [0.75706005, 0.91962279, 0.53064994, ..., 0.40822447,
#           0.58230893, 0.7726001 ],
#          [0.75706005, 0.91962279, 0.48518142, ..., 0.94924546,
#           0.58230893, 0.7726001 ],
#          [0.75706005, 0.91962279, 0.55101418, ..., 0.63361966,
#           0.98077455, 0.7726001 ]]],
#
#
#        [[[0.91629742, 0.91962279, 0.90937016, ..., 0.48072903,
#           0.58230893, 0.7726001 ],
#          [0.75706005, 0.91962279, 0.46750631, ..., 0.66945363,
#           0.89069656, 0.7726001 ],
#          [0.75706005, 0.91962279, 0.32546571, ..., 0.19029647,
#           0.99921276, 0.7726001 ],
#          ...,
#          [0.75706005, 0.91962279, 0.32546571, ..., 0.32776497,
#           0.58230893, 0.7726001 ],
#          [0.78128059, 0.91962279, 0.43059035, ..., 0.31073781,
#           0.58230893, 0.7726001 ],
#          [0.75706005, 0.91962279, 0.88388025, ..., 0.97818845,
#           0.94751033, 0.7726001 ]],
#
#         [[0.75706005, 0.91962279, 0.60831175, ..., 0.71673661,
#           0.58230893, 0.7726001 ],
#          [0.99164801, 0.91962279, 0.48991284, ..., 0.47964248,
#           0.58230893, 0.7726001 ],
#          [0.75706005, 0.91962279, 0.84186579, ..., 0.72002452,
#           0.58230893, 0.7726001 ],
#          ...,
#          [0.75706005, 0.91962279, 0.79273002, ..., 0.07366457,
#           0.76311587, 0.90820526],
#          [0.75706005, 0.91962279, 0.70624522, ..., 0.25947808,
#           0.58230893, 0.7726001 ],
#          [0.81796451, 0.91962279, 0.70757058, ..., 0.37698906,
#           0.88437013, 0.7726001 ]],
#
#         [[0.75706005, 0.91962279, 0.48907851, ..., 0.91374216,
#           0.58230893, 0.7726001 ],
#          [0.75706005, 0.91962279, 0.32546571, ..., 0.40344257,
#           0.58230893, 0.95725814],
#          [0.75706005, 0.91962279, 0.93570144, ..., 0.10863911,
#           0.58230893, 0.83687821],
#          ...,
#          [0.75706005, 0.91962279, 0.32546571, ..., 0.12500431,
#           0.58230893, 0.7726001 ],
#          [0.75706005, 0.91962279, 0.60701466, ..., 0.18810005,
#           0.65127983, 0.84008836],
#          [0.75706005, 0.91962279, 0.97491723, ..., 0.25606634,
#           0.58230893, 0.7726001 ]]],
#
#
#        [[[0.94384363, 0.91962279, 0.94325519, ..., 0.28869705,
#           0.79413849, 0.7726001 ],
#          [0.75706005, 0.91962279, 0.97909505, ..., 0.98751873,
#           0.58230893, 0.7726001 ],
#          [0.93512159, 0.91962279, 0.88311551, ..., 0.89407484,
#           0.58230893, 0.97074748],
#          ...,
#          [0.75706005, 0.91962279, 0.32546571, ..., 0.70708942,
#           0.66006084, 0.7726001 ],
#          [0.75706005, 0.91962279, 0.6600591 , ..., 0.96292441,
#           0.58230893, 0.7726001 ],
#          [0.75706005, 0.91962279, 0.32546571, ..., 0.07366457,
#           0.58230893, 0.95621484]],
#
#         [[0.90892911, 0.91962279, 0.52006614, ..., 0.11183106,
#           0.99028163, 0.7726001 ],
#          [0.91939443, 0.91962279, 0.32546571, ..., 0.07366457,
#           0.81004843, 0.7726001 ],
#          [0.75706005, 0.91962279, 0.54013615, ..., 0.12601702,
#           0.58230893, 0.7726001 ],
#          ...,
#          [0.93708194, 0.91962279, 0.32546571, ..., 0.10126499,
#           0.65542027, 0.7726001 ],
#          [0.75706005, 0.91962279, 0.32546571, ..., 0.37328031,
#           0.58230893, 0.7726001 ],
#          [0.75706005, 0.91962279, 0.72227678, ..., 0.71237193,
#           0.58230893, 0.7726001 ]],
#
#         [[0.75706005, 0.91962279, 0.32546571, ..., 0.26180823,
#           0.58230893, 0.7726001 ],
#          [0.75706005, 0.91962279, 0.36722105, ..., 0.43387279,
#           0.86129626, 0.99653026],
#          [0.75706005, 0.91962279, 0.32546571, ..., 0.31672637,
#           0.58230893, 0.88480983],
#          ...,
#          [0.75706005, 0.91962279, 0.35771512, ..., 0.57801457,
#           0.58230893, 0.7726001 ],
#          [0.88030961, 0.91962279, 0.42257167, ..., 0.58014296,
#           0.58230893, 0.7726001 ],
#          [0.75706005, 0.91962279, 0.50803661, ..., 0.46400931,
#           0.81547567, 0.9542753 ]]]])

# %%
z.shape
# Out:
# (64, 3, 132, 10)

# %%
A=[1,2,3,4,5]
B=[5,4,3,2,1]

# %%
np.dot(A,B)
# Out:
# 35

# %%
A = np.array( [[1,2],
               [3,4]] )
B = np.array( [[5,6],
               [7,8]] )

# %%
A.dot(B)
# Out:
# array([[19, 22],
#        [43, 50]])

# %%
A=np.array([1,2,3,4]).reshape(4,1)
B=np.array([1,2,3,4,5,6,7,8]).reshape(2,4)

# %%
A.shape
# Out:
# (4, 1)

# %%
B.shape
# Out:
# (2, 4)

# %%
np.dot(A,B)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-51-189f80e2c351> in <module>
# ----> 1 np.dot(A,B)
#
# <__array_function__ internals> in dot(*args, **kwargs)
#
# ValueError: shapes (4,1) and (2,4) not aligned: 1 (dim 1) != 2 (dim 0)

# %%
np.dot(B,A)
# Out:
# array([[30],
#        [70]])

# %%
B.dot(A)
# Out:
# array([[30],
#        [70]])
