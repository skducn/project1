# %%
import pandas as pd
import numpy as np
df = pd.read_csv('c:/000625.csv',encoding='utf8')
df
# Out:
#      Unnamed: 0    ts_code  trade_date   open   high    low  close  pre_close  \
# 0             0  000625.SZ    20210611  23.20  23.99  22.23  23.29      23.29
# 1             1  000625.SZ    20210610  22.23  23.67  22.12  23.29      22.53
# 2             2  000625.SZ    20210609  22.50  22.83  22.10  22.53      22.51
# 3             3  000625.SZ    20210608  22.68  23.45  22.06  22.51      22.80
# 4             4  000625.SZ    20210607  23.58  23.75  22.38  22.80      23.58
# ..          ...        ...         ...    ...    ...    ...    ...        ...
# 101         101  000625.SZ    20210108  22.90  23.59  21.80  23.43      22.69
# 102         102  000625.SZ    20210107  21.34  23.00  20.60  22.69      21.13
# 103         103  000625.SZ    20210106  21.30  21.73  20.60  21.13      21.03
# 104         104  000625.SZ    20210105  21.89  22.11  20.95  21.03      21.75
# 105         105  000625.SZ    20210104  21.20  22.30  21.01  21.75      21.88
#
# ...

# %%
df.pivot_table(index="trade_date",values=["open","close","vol"])
# Out:
#             close   open         vol
# trade_date
# 20210104    21.75  21.20  1359361.28
# 20210105    21.03  21.89  1482878.57
# 20210106    21.13  21.30  1250232.45
# 20210107    22.69  21.34  2594173.97
# 20210108    23.43  22.90  2363164.71
# ...           ...    ...         ...
# 20210607    22.80  23.58  1612557.30
# 20210608    22.51  22.68  1330301.24
# 20210609    22.53  22.50   904285.45
# 20210610    23.29  22.23  1735938.09
# 20210611    23.29  23.20  2018951.06
#
# [106 rows x 3 columns]

# %%
df.pivot_table(index="trade_date",values=["open","close","vol"],aggfunc=[df[df['vol']>df['vol'].mean()]])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-7a8ed59bebd0> in <module>
# ----> 1 df.pivot_table(index="trade_date",values=["open","close","vol"],aggfunc=[df[df['vol']>df['vol'].mean()]])
#
# c:\python39\lib\site-packages\pandas\core\frame.py in pivot_table(self, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed)
#    7026         from pandas.core.reshape.pivot import pivot_table
#    7027
# -> 7028         return pivot_table(
#    7029             self,
#    7030             values=values,
#
# c:\python39\lib\site-packages\pandas\core\reshape\pivot.py in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed)
#      56         keys = []
#      57         for func in aggfunc:
# ---> 58             table = pivot_table(
#      59                 data,
# ...

# %%
df[df['vol']>df['vol'].mean()]
# Out:
#      Unnamed: 0    ts_code  trade_date   open   high    low  close  pre_close  \
# 0             0  000625.SZ    20210611  23.20  23.99  22.23  23.29      23.29
# 1             1  000625.SZ    20210610  22.23  23.67  22.12  23.29      22.53
# 4             4  000625.SZ    20210607  23.58  23.75  22.38  22.80      23.58
# 5             5  000625.SZ    20210604  23.21  24.25  22.88  23.58      23.40
# 6             6  000625.SZ    20210603  23.10  23.90  22.45  23.40      22.96
# 7             7  000625.SZ    20210602  23.50  23.93  22.77  22.96      23.79
# 8             8  000625.SZ    20210601  23.40  24.69  23.20  23.79      23.75
# 9             9  000625.SZ    20210531  22.70  24.10  22.20  23.75      23.04
# 10           10  000625.SZ    20210528  21.72  23.70  21.30  23.04      21.76
# 11           11  000625.SZ    20210527  22.50  22.60  21.56  21.76      22.15
# 12           12  000625.SZ    20210526  21.51  22.52  21.51  22.15      21.50
# ...
