# %%
import pandas as pd
import numpy as np
df = pd.read_excel("erp.xlsx",sheet_name=0)

# %%
df.head(4)
# Out:
#   区域经理 代表姓名                     医院  预估月患者数   总患者数 客户姓名  科室     职称    职务 客户关系  \
# 0   刘挺   黄淼  上海市宝山区张庙街道长江路社区卫生服务中心     534  26410  陈培森 NaN  副主任医师    主任   3级
# 1   刘挺   黄淼  上海市宝山区张庙街道长江路社区卫生服务中心     534  26410   冯群 NaN  副主任医师  门办主任   5级
# 2   刘挺   黄淼  上海市宝山区张庙街道长江路社区卫生服务中心     534  26410   杨蓉 NaN  副主任医师   NaN  NaN
# 3   刘挺   黄淼  上海市宝山区张庙街道长江路社区卫生服务中心     534  26410  植家喜 NaN     主治   NaN  NaN
#
#    ... 床位数  月度床位周转次数  月出院人数  高血压患者比例.1  随访周期（周）  病例管理潜力  目前病例数（人）  目标病例数（人）  \
# 0  ...  12       3.0     36       0.40      4.0   814.4        70       NaN
# 1  ...  10       4.0     40       0.35      2.0   259.0        14       NaN
# 2  ...   5       4.0     20       0.45      6.0   283.5        86       NaN
# 3  ...   0       NaN      0       0.40      4.0     NaN        80       NaN
#
#    潜力值排名  患者认可度排名
# 0      A        A
# 1      A        A
# 2      A        A
# 3    NaN      NaN
#
# [4 rows x 28 columns]

# %%
df.shape
# Out:
# (9, 28)

# %%
df.info
# Out:
# <bound method DataFrame.info of   区域经理 代表姓名                     医院  预估月患者数   总患者数 客户姓名  科室     职称    职务 客户关系  \
# 0   刘挺   黄淼  上海市宝山区张庙街道长江路社区卫生服务中心     534  26410  陈培森 NaN  副主任医师    主任   3级
# 1   刘挺   黄淼  上海市宝山区张庙街道长江路社区卫生服务中心     534  26410   冯群 NaN  副主任医师  门办主任   5级
# 2   刘挺   黄淼  上海市宝山区张庙街道长江路社区卫生服务中心     534  26410   杨蓉 NaN  副主任医师   NaN  NaN
# 3   刘挺   黄淼  上海市宝山区张庙街道长江路社区卫生服务中心     534  26410  植家喜 NaN     主治   NaN  NaN
# 4   刘挺   黄淼  上海市宝山区张庙街道长江路社区卫生服务中心     534  26410  鄢奉斌 NaN     主治   NaN  NaN
# 5   刘挺   黄淼  上海市宝山区张庙街道长江路社区卫生服务中心     534  26410  金黎菊 NaN     主治   NaN  NaN
# 6   刘挺   黄淼  上海市宝山区张庙街道长江路社区卫生服务中心     534  26410   施燕 NaN  副主任医师   NaN  NaN
# 7   刘挺   黄淼  上海市宝山区张庙街道长江路社区卫生服务中心     534  26410   黄伟 NaN     主治   NaN  NaN
# 8   刘挺   黄淼  上海市宝山区张庙街道长江路社区卫生服务中心     534  26410  朱永平 NaN     主治   NaN  NaN
#
#    ... 床位数  月度床位周转次数  月出院人数  高血压患者比例.1  随访周期（周）  病例管理潜力  目前病例数（人）  目标病例数（人）  \
# 0  ...  12       3.0     36       0.40      4.0   814.4        70       NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3219 entries, 0 to 3218
# Data columns (total 33 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   区域经理       3219 non-null   object
#  1   代表姓名       3219 non-null   object
#  2   医院         3219 non-null   object
#  3   预估月患者数     3219 non-null   int64
#  4   总患者数       3219 non-null   float64
#  5   客户姓名       3215 non-null   object
#  6   科室         0 non-null      float64
#  7   职称         3214 non-null   object
#  8   职务         449 non-null    object
#  9   客户关系       2 non-null      object
#  10  竞品1        1 non-null      object
#  11  竞品2        1 non-null      object
#  12  竞品3        0 non-null      float64
#  13  门诊天数       3188 non-null   float64
#  14  日门诊量       3188 non-null   float64
#  15  月门诊量       3190 non-null   float64
#  16  高血压患者比例    19 non-null     float64
#  17  月高血压患者数    3194 non-null   float64
#  18  复诊周期（周）    7 non-null      float64
# ...

# %%
df.isnull()
# Out:
#     区域经理   代表姓名     医院  预估月患者数   总患者数   客户姓名    科室     职称     职务   客户关系  ...  \
# 0  False  False  False   False  False  False  True  False  False  False  ...
# 1  False  False  False   False  False  False  True  False  False  False  ...
# 2  False  False  False   False  False  False  True  False   True   True  ...
# 3  False  False  False   False  False  False  True  False   True   True  ...
# 4  False  False  False   False  False  False  True  False   True   True  ...
# 5  False  False  False   False  False  False  True  False   True   True  ...
# 6  False  False  False   False  False  False  True  False   True   True  ...
# 7  False  False  False   False  False  False  True  False   True   True  ...
# 8  False  False  False   False  False  False  True  False   True   True  ...
#
#      床位数  月度床位周转次数  月出院人数  高血压患者比例.1  随访周期（周）  病例管理潜力  目前病例数（人）  目标病例数（人）  \
# 0  False     False  False      False    False   False     False      True
# ...

# %%
df["职称"].unique()
# Out:
# array(['副主任医师', '主治'], dtype=object)

# %%
df["职称"].unique()[0]
# Out:
# '副主任医师'

# %%
df.values[1][5]
# Out:
# '冯群'

# %%
df.columns
# Out:
# Index(['区域经理', '代表姓名', '医院', '预估月患者数', '总患者数', '客户姓名', '科室', '职称', '职务',
#        '客户关系', '竞品1', '竞品2', '竞品3', '门诊天数', '日门诊量', '月门诊量', '高血压患者比例',
#        '复诊周期（周）', '床位数', '月度床位周转次数', '月出院人数', '高血压患者比例.1', '随访周期（周）', '病例管理潜力',
#        '目前病例数（人）', '目标病例数（人）', '潜力值排名', '患者认可度排名'],
#       dtype='object')

# %%
df.columns[1]
# Out:
# '代表姓名'
