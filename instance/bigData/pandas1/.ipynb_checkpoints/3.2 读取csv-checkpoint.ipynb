# %%
import pandas as pd
import numpy as np

# %%
pd.__version__
# Out:
# '1.5.3'

# %%
df = pd.read_csv('https://www.gairuo.com/file/data/dataset/GDP-China.csv')
df.head()
# Out:
#      年份     国民总收入    国内生产总值  第一产业增加值   第二产业增加值   第三产业增加值  人均国内生产总值
# 0  2018  896915.6  900309.5  64734.0  366000.9  469574.6     64644
# 1  2017  820099.5  820754.3  62099.5  332742.7  425912.1     59201
# 2  2016  737074.0  740060.8  60139.2  296547.7  383373.9     53680
# 3  2015  683390.5  685992.9  57774.6  282040.3  346178.0     50028
# 4  2014  642097.6  641280.6  55626.3  277571.8  308082.5     47005

# %%
from io import StringIO

# %%
# 数据字符串
data=('col1,col2,col3\n''a,b,1\n''c,d,3')
pd.read_csv(StringIO(data))
# Out:
#   col1 col2  col3
# 0    a    b     1
# 1    c    d     3

# %%
pd.read_csv(StringIO(data),dtype=object)
# Out:
#   col1 col2 col3
# 0    a    b    1
# 1    c    d    3

# %%
# 3.2.4 表头 header
df = pd.read_csv('https://www.gairuo.com/file/data/dataset/GDP-China.csv',header=0)
df.head()
# Out:
#      年份     国民总收入    国内生产总值  第一产业增加值   第二产业增加值   第三产业增加值  人均国内生产总值
# 0  2018  896915.6  900309.5  64734.0  366000.9  469574.6     64644
# 1  2017  820099.5  820754.3  62099.5  332742.7  425912.1     59201
# 2  2016  737074.0  740060.8  60139.2  296547.7  383373.9     53680
# 3  2015  683390.5  685992.9  57774.6  282040.3  346178.0     50028
# 4  2014  642097.6  641280.6  55626.3  277571.8  308082.5     47005

# %%
# 无表头
df = pd.read_csv('https://www.gairuo.com/file/data/dataset/GDP-China.csv',header=None)
df.head()
# Out:
#       0         1         2        3         4         5         6
# 0    年份     国民总收入    国内生产总值  第一产业增加值   第二产业增加值   第三产业增加值  人均国内生产总值
# 1  2018  896915.6  900309.5    64734  366000.9  469574.6     64644
# 2  2017  820099.5  820754.3  62099.5  332742.7  425912.1     59201
# 3  2016    737074  740060.8  60139.2  296547.7  383373.9     53680
# 4  2015  683390.5  685992.9  57774.6  282040.3    346178     50028

# %%
# 多表头
df = pd.read_csv('https://www.gairuo.com/file/data/dataset/GDP-China.csv',header=[0,1,3])
df.head()
# Out:
#      年份     国民总收入    国内生产总值  第一产业增加值   第二产业增加值   第三产业增加值 人均国内生产总值
#    2018  896915.6  900309.5    64734  366000.9  469574.6    64644
#    2016    737074  740060.8  60139.2  296547.7  383373.9    53680
# 0  2015  683390.5  685992.9  57774.6  282040.3  346178.0    50028
# 1  2014  642097.6  641280.6  55626.3  277571.8  308082.5    47005
# 2  2013  588141.2  592963.2  53028.1  261956.1  277979.1    43684
# 3  2012  537329.0  538580.0  49084.5  244643.3  244852.2    39874
# 4  2011  483392.8  487940.2  44781.4  227038.8  216120.0    36302

# %%
# 3.2.5 列名 names
df = pd.read_csv('https://www.gairuo.com/file/data/dataset/GDP-China.csv',names=['测试一下'])
df.head()
# Out:
#                                                       测试一下
# 年份   国民总收入    国内生产总值   第一产业增加值 第二产业增加值  第三产业增加值   人均国内生产总值
# 2018 896915.6 900309.5 64734   366000.9 469574.6     64644
# 2017 820099.5 820754.3 62099.5 332742.7 425912.1     59201
# 2016 737074   740060.8 60139.2 296547.7 383373.9     53680
# 2015 683390.5 685992.9 57774.6 282040.3 346178       50028

# %%
df = pd.read_csv('https://www.gairuo.com/file/data/dataset/GDP-China.csv',names=['年份','国内生产总值'],header=None)
df.head()
# Out:
#                                                年份    国内生产总值
# 年份   国民总收入    国内生产总值   第一产业增加值 第二产业增加值    第三产业增加值  人均国内生产总值
# 2018 896915.6 900309.5 64734   366000.9  469574.6     64644
# 2017 820099.5 820754.3 62099.5 332742.7  425912.1     59201
# 2016 737074   740060.8 60139.2 296547.7  383373.9     53680
# 2015 683390.5 685992.9 57774.6 282040.3    346178     50028

# %%
# 默认索引
df = pd.read_csv('https://www.gairuo.com/file/data/dataset/GDP-China.csv',index_col=False)
df.head()
# Out:
#      年份     国民总收入    国内生产总值  第一产业增加值   第二产业增加值   第三产业增加值  人均国内生产总值
# 0  2018  896915.6  900309.5  64734.0  366000.9  469574.6     64644
# 1  2017  820099.5  820754.3  62099.5  332742.7  425912.1     59201
# 2  2016  737074.0  740060.8  60139.2  296547.7  383373.9     53680
# 3  2015  683390.5  685992.9  57774.6  282040.3  346178.0     50028
# 4  2014  642097.6  641280.6  55626.3  277571.8  308082.5     47005

# %%
# 3.2.6 设置索引 index_col
df = pd.read_csv('https://www.gairuo.com/file/data/dataset/GDP-China.csv',index_col=6)
df.head()
# Out:
#             年份     国民总收入    国内生产总值  第一产业增加值   第二产业增加值   第三产业增加值
# 人均国内生产总值
# 64644     2018  896915.6  900309.5  64734.0  366000.9  469574.6
# 59201     2017  820099.5  820754.3  62099.5  332742.7  425912.1
# 53680     2016  737074.0  740060.8  60139.2  296547.7  383373.9
# 50028     2015  683390.5  685992.9  57774.6  282040.3  346178.0
# 47005     2014  642097.6  641280.6  55626.3  277571.8  308082.5

# %%
df = pd.read_csv('https://www.gairuo.com/file/data/dataset/GDP-China.csv',index_col='年份')
df.head()
# Out:
#          国民总收入    国内生产总值  第一产业增加值   第二产业增加值   第三产业增加值  人均国内生产总值
# 年份
# 2018  896915.6  900309.5  64734.0  366000.9  469574.6     64644
# 2017  820099.5  820754.3  62099.5  332742.7  425912.1     59201
# 2016  737074.0  740060.8  60139.2  296547.7  383373.9     53680
# 2015  683390.5  685992.9  57774.6  282040.3  346178.0     50028
# 2014  642097.6  641280.6  55626.3  277571.8  308082.5     47005

# %%
df = pd.read_csv('https://www.gairuo.com/file/data/dataset/GDP-China.csv',index_col=[1,3])
df.head()
# Out:
#                     年份    国内生产总值   第二产业增加值   第三产业增加值  人均国内生产总值
# 国民总收入    第一产业增加值
# 896915.6 64734.0  2018  900309.5  366000.9  469574.6     64644
# 820099.5 62099.5  2017  820754.3  332742.7  425912.1     59201
# 737074.0 60139.2  2016  740060.8  296547.7  383373.9     53680
# 683390.5 57774.6  2015  685992.9  282040.3  346178.0     50028
# 642097.6 55626.3  2014  641280.6  277571.8  308082.5     47005

# %%
# 3.2.7 使用部分列 usecols
df = pd.read_csv('https://www.gairuo.com/file/data/dataset/GDP-China.csv',usecols=[0,4,3])
df.head()
# Out:
#      年份  第一产业增加值   第二产业增加值
# 0  2018  64734.0  366000.9
# 1  2017  62099.5  332742.7
# 2  2016  60139.2  296547.7
# 3  2015  57774.6  282040.3
# 4  2014  55626.3  277571.8

# %%
df = pd.read_csv('https://www.gairuo.com/file/data/dataset/GDP-China.csv',usecols=[0,4,3],index_col=1)
df.head()
# Out:
#            年份   第二产业增加值
# 第一产业增加值
# 64734.0  2018  366000.9
# 62099.5  2017  332742.7
# 60139.2  2016  296547.7
# 57774.6  2015  282040.3
# 55626.3  2014  277571.8

# %%
# 指定列的顺序
df = pd.read_csv('https://www.gairuo.com/file/data/dataset/GDP-China.csv',usecols=[0,4,3])[['第二产业增加值','年份']]
df.head()
# Out:
#     第二产业增加值    年份
# 0  366000.9  2018
# 1  332742.7  2017
# 2  296547.7  2016
# 3  282040.3  2015
# 4  277571.8  2014

# %%
# 3.2.11 数据类型 dtype
df = pd.read_csv('https://www.gairuo.com/file/data/dataset/GDP-China.csv', dtype=np.float64)
df.head()
# Out:
#        年份     国民总收入    国内生产总值  第一产业增加值   第二产业增加值   第三产业增加值  人均国内生产总值
# 0  2018.0  896915.6  900309.5  64734.0  366000.9  469574.6   64644.0
# 1  2017.0  820099.5  820754.3  62099.5  332742.7  425912.1   59201.0
# 2  2016.0  737074.0  740060.8  60139.2  296547.7  383373.9   53680.0
# 3  2015.0  683390.5  685992.9  57774.6  282040.3  346178.0   50028.0
# 4  2014.0  642097.6  641280.6  55626.3  277571.8  308082.5   47005.0

# %%
df = pd.read_csv('https://www.gairuo.com/file/data/dataset/GDP-China.csv', dtype={'年份':np.float64})
df.head()
# Out:
#        年份     国民总收入    国内生产总值  第一产业增加值   第二产业增加值   第三产业增加值  人均国内生产总值
# 0  2018.0  896915.6  900309.5  64734.0  366000.9  469574.6     64644
# 1  2017.0  820099.5  820754.3  62099.5  332742.7  425912.1     59201
# 2  2016.0  737074.0  740060.8  60139.2  296547.7  383373.9     53680
# 3  2015.0  683390.5  685992.9  57774.6  282040.3  346178.0     50028
# 4  2014.0  642097.6  641280.6  55626.3  277571.8  308082.5     47005

# %%
# 3.2.13 列数据处理 converters
data = 'x,y\na,1\nb,2'
def foo(p):
    return p + 's'
pd.read_csv(StringIO(data),converters={'x':foo,'y':lambda x:x*3})
# Out:
#     x    y
# 0  as  111
# 1  bs  222

# %%
pd.read_csv(StringIO(data),converters={0:foo,1:lambda x:x*3})
# Out:
#     x    y
# 0  as  111
# 1  bs  222

# %%
# 3.2.14 真假值转换 true_values false_values
data= ('a,b,c\n1,Yes,2\n3,No,4')
pd.read_csv(StringIO(data),true_values=['Yes'], false_values=['No'])
# Out:
#    a      b  c
# 0  1   True  2
# 1  3  False  4

# %%
df = pd.read_csv('GDP-China.csv')
df.head()
# Out:
#        年份     国民总收入    国内生产总值  第一产业增加值   第二产业增加值   第三产业增加值  人均国内生产总值
# 0  2018.0  896915.6  900309.5  64734.0  366000.9  469574.6   64644.0  \
# 1     NaN       NaN       NaN      NaN       NaN       NaN       NaN
# 2  2016.0  737074.0  740060.8  60139.2  296547.7  383373.9   53680.0
# 3  2015.0  683390.5  685992.9  57774.6  282040.3  346178.0   50028.0
# 4  2014.0  642097.6  641280.6  55626.3  277571.8  308082.5   47005.0
#
#                   日期
# 0           20201230
# 1         2020/12/30
# 2  20201230 10:12:13
# 3  12/30/20 10:12:13
# 4   2020/12/30 11:22

# %%
# 3.2.15 跳过空行 没有看到效果 skip_blank_lines
df = pd.read_csv('GDP-China.csv', skip_blank_lines=True)
df.head()
# Out:
#        年份     国民总收入    国内生产总值  第一产业增加值   第二产业增加值   第三产业增加值  人均国内生产总值
# 0  2018.0  896915.6  900309.5  64734.0  366000.9  469574.6   64644.0  \
# 1     NaN       NaN       NaN      NaN       NaN       NaN       NaN
# 2  2016.0  737074.0  740060.8  60139.2  296547.7  383373.9   53680.0
# 3  2015.0  683390.5  685992.9  57774.6  282040.3  346178.0   50028.0
# 4  2014.0  642097.6  641280.6  55626.3  277571.8  308082.5   47005.0
#
#                   日期
# 0           20201230
# 1         2020/12/30
# 2  20201230 10:12:13
# 3  12/30/20 10:12:13
# 4   2020/12/30 11:22

# %%
# 3.2.16 读取指定的行 nrows
df = pd.read_csv('GDP-China.csv', nrows=4)
df.head()
# Out:
#        年份     国民总收入    国内生产总值  第一产业增加值   第二产业增加值   第三产业增加值  人均国内生产总值
# 0  2018.0  896915.6  900309.5  64734.0  366000.9  469574.6   64644.0  \
# 1     NaN       NaN       NaN      NaN       NaN       NaN       NaN
# 2  2016.0  737074.0  740060.8  60139.2  296547.7  383373.9   53680.0
# 3  2015.0  683390.5  685992.9  57774.6  282040.3  346178.0   50028.0
#
#                   日期
# 0           20201230
# 1         2020/12/30
# 2  20201230 10:12:13
# 3  12/30/20 10:12:13

# %%
# 3.2.17 空值替换 na_values
df = pd.read_csv('GDP-China.csv', na_values=[2016])
df.head()
# Out:
#        年份     国民总收入    国内生产总值  第一产业增加值   第二产业增加值   第三产业增加值  人均国内生产总值
# 0  2018.0  896915.6  900309.5  64734.0  366000.9  469574.6   64644.0  \
# 1     NaN       NaN       NaN      NaN       NaN       NaN       NaN
# 2     NaN  737074.0  740060.8  60139.2  296547.7  383373.9   53680.0
# 3  2015.0  683390.5  685992.9  57774.6  282040.3  346178.0   50028.0
# 4  2014.0  642097.6  641280.6  55626.3  277571.8  308082.5   47005.0
#
#                   日期
# 0           20201230
# 1         2020/12/30
# 2  20201230 10:12:13
# 3  12/30/20 10:12:13
# 4   2020/12/30 11:22

# %%
# 不自动识别空值NaN
df = pd.read_csv('GDP-China.csv', keep_default_na=False, na_values=[2016])
df.head()
# Out:
#      年份     国民总收入    国内生产总值  第一产业增加值   第二产业增加值   第三产业增加值 人均国内生产总值
# 0  2018  896915.6  900309.5    64734  366000.9  469574.6    64644  \
# 1
# 2   NaN    737074  740060.8  60139.2  296547.7  383373.9    53680
# 3  2015  683390.5  685992.9  57774.6  282040.3    346178    50028
# 4  2014  642097.6  641280.6  55626.3  277571.8  308082.5    47005
#
#                   日期
# 0           20201230
# 1         2020/12/30
# 2  20201230 10:12:13
# 3  12/30/20 10:12:13
# 4   2020/12/30 11:22

# %%
# 不检查丢失值（空字符串或空值），
df = pd.read_csv('GDP-China.csv', na_filter=False)
df.head()
# Out:
#      年份     国民总收入    国内生产总值  第一产业增加值   第二产业增加值   第三产业增加值 人均国内生产总值
# 0  2018  896915.6  900309.5    64734  366000.9  469574.6    64644  \
# 1
# 2  2016    737074  740060.8  60139.2  296547.7  383373.9    53680
# 3  2015  683390.5  685992.9  57774.6  282040.3    346178    50028
# 4  2014  642097.6  641280.6  55626.3  277571.8  308082.5    47005
#
#                   日期
# 0           20201230
# 1         2020/12/30
# 2  20201230 10:12:13
# 3  12/30/20 10:12:13
# 4   2020/12/30 11:22

# %%
df = pd.read_csv('GDP-China.csv', dayfirst=True,parse_dates=[7])
df.head()
# Out:
# /var/folders/f7/4z7jtb213fs0mtgbw_0vs2600000gn/T/ipykernel_1170/780447371.py:1: UserWarning: Parsing dates in %Y%m%d format when dayfirst=True was specified. Pass `dayfirst=False` or specify a format to silence this warning.
#   df = pd.read_csv('GDP-China.csv', dayfirst=True,parse_dates=[7])
#        年份     国民总收入    国内生产总值  第一产业增加值   第二产业增加值   第三产业增加值  人均国内生产总值
# 0  2018.0  896915.6  900309.5  64734.0  366000.9  469574.6   64644.0  \
# 1     NaN       NaN       NaN      NaN       NaN       NaN       NaN
# 2  2016.0  737074.0  740060.8  60139.2  296547.7  383373.9   53680.0
# 3  2015.0  683390.5  685992.9  57774.6  282040.3  346178.0   50028.0
# 4  2014.0  642097.6  641280.6  55626.3  277571.8  308082.5   47005.0
#
#                   日期
# 0           20201230
# 1         2020/12/30
# 2  20201230 10:12:13
# 3  12/30/20 10:12:13
# 4   2020/12/30 11:22

# %%
print(df.to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#       <th>1</th>
#       <th>2</th>
#       <th>3</th>
#       <th>4</th>
#       <th>5</th>
#       <th>6</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>年份</td>
#       <td>国民总收入</td>
#       <td>国内生产总值</td>
#       <td>第一产业增加值</td>
#       <td>第二产业增加值</td>
#       <td>第三产业增加值</td>
#       <td>人均国内生产总值</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2018</td>
#       <td>896915.6</td>
#       <td>900309.5</td>
#       <td>64734</td>
#       <td>366000.9</td>
#       <td>469574.6</td>
#       <td>64644</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2017</td>
#       <td>820099.5</td>
#       <td>820754.3</td>
#       <td>62099.5</td>
#       <td>332742.7</td>
#       <td>425912.1</td>
#       <td>59201</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>2016</td>
#       <td>737074</td>
# ...

# %%
print(df.head().to_markdown())
# Out:
# |    | 0    | 1          | 2            | 3              | 4              | 5              | 6                |
# |---:|:-----|:-----------|:-------------|:---------------|:---------------|:---------------|:-----------------|
# |  0 | 年份 | 国民总收入 | 国内生产总值 | 第一产业增加值 | 第二产业增加值 | 第三产业增加值 | 人均国内生产总值 |
# |  1 | 2018 | 896915.6   | 900309.5     | 64734          | 366000.9       | 469574.6       | 64644            |
# |  2 | 2017 | 820099.5   | 820754.3     | 62099.5        | 332742.7       | 425912.1       | 59201            |
# |  3 | 2016 | 737074     | 740060.8     | 60139.2        | 296547.7       | 383373.9       | 53680            |
# |  4 | 2015 | 683390.5   | 685992.9     | 57774.6        | 282040.3       | 346178         | 50028            |

# %%
df = df.head()

# %%
# 3.4.1 将df内容另存为test.csv并压缩成test.zip
com = dict(method='zip',archive_name='test.csv')
df.to_csv('test.zip',index=False,compression=com)

# %%
a="11"
